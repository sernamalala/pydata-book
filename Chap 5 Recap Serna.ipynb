# %% [markdown]
# #### Pandas Important bits

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40], index=["a","b","c","d"])

# %%
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# Series is a column of sorts that we can index

# %%
p = pd.Series(["Serna","Ketsia","Tychique","Keren"])

# %%
print(p)
# Out:
# 0       Serna
# 1      Ketsia
# 2    Tychique
# 3       Keren
# dtype: object

# %% [markdown]
# automatic indexing, when we dont declare indexing

# %%
data = {"Name":["Serna","Ketsia","Keren","Tychique","Premi"],"Age":[22,8,17,20,8],"Salary":[0,0,0,0,0]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 1    Ketsia    8       0
# 2     Keren   17       0
# 3  Tychique   20       0
# 4     Premi    8       0

# %% [markdown]
# data frames are multiple columns of series in a way

# %%
df.to_csv("ouput.csv",index=False)

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\serna\OneDrive - Cape Peninsula University of Technology\Desktop\Class Materials 2025\ARTIFICIAL INTELLIGENCE 5\Data Analysis\pydata-book

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'appa.ipynb', 'appb.ipynb', 'ch02.ipynb', 'ch03.ipynb', 'ch04.ipynb', 'ch05(notes)v2.ipynb', 'ch05.ipynb', 'ch06.ipynb', 'ch07.ipynb', 'ch08.ipynb', 'ch09.ipynb', 'ch10.ipynb', 'ch11.ipynb', 'ch12.ipynb', 'ch13.ipynb', 'ch6&9primer.ipynb', 'COPYING', 'datasets', 'examples', 'ouput.csv', 'README.md', 'requirements.txt', 'Untitled.ipynb']

# %%
reading = pd.read_csv(r"ouput.csv")

# %% [markdown]
# use "r" when declaring the path

# %%
print(reading)
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 1    Ketsia    8       0
# 2     Keren   17       0
# 3  Tychique   20       0
# 4     Premi    8       0

# %%
print(df.head())
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 1    Ketsia    8       0
# 2     Keren   17       0
# 3  Tychique   20       0
# 4     Premi    8       0

# %% [markdown]
# head prints out 1st five rows

# %%
print(df.tail())
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 1    Ketsia    8       0
# 2     Keren   17       0
# 3  Tychique   20       0
# 4     Premi    8       0

# %% [markdown]
# tail prints out last five rows

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Salary  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# None

# %%
print(df.describe())
# Out:
#             Age  Salary
# count   5.00000     5.0
# mean   15.00000     0.0
# std     6.63325     0.0
# min     8.00000     0.0
# 25%     8.00000     0.0
# 50%    17.00000     0.0
# 75%    20.00000     0.0
# max    22.00000     0.0

# %%
print(df.shape)
# Out:
# (5, 3)

# %% [markdown]
# shape tells us the order of the matrix/table

# %%
df["Name"]
# Out:
# 0       Serna
# 1      Ketsia
# 2       Keren
# 3    Tychique
# 4       Premi
# Name: Name, dtype: object

# %%
df[["Name","Age"]]
# Out:
#        Name  Age
# 0     Serna   22
# 1    Ketsia    8
# 2     Keren   17
# 3  Tychique   20
# 4     Premi    8

# %% [markdown]
# select columns, like selecting from an object

# %%
df[df["Age"]>10]
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 2     Keren   17       0
# 3  Tychique   20       0

# %%
df[df["Name"] == "Serna"]
# Out:
#     Name  Age  Salary
# 0  Serna   22       0

# %%
df.loc[0,"Age"]
# Out:
# 22

# %%
df.iloc[0,0]
# Out:
# 'Serna'

# %%
df.iloc[0,:]
# Out:
# Name      Serna
# Age          22
# Salary        0
# Name: 0, dtype: object

# %%
df.iloc[0,0:]
# Out:
# Name      Serna
# Age          22
# Salary        0
# Name: 0, dtype: object

# %%
df.iloc[0:2,0:]
# Out:
#      Name  Age  Salary
# 0   Serna   22       0
# 1  Ketsia    8       0

# %%
df.fillna(100)
# Out:
#        Name  Age  Salary
# 0     Serna   22       0
# 1    Ketsia    8       0
# 2     Keren   17       0
# 3  Tychique   20       0
# 4     Premi    8       0

# %%
df["Salary"] = 1000

# %%
df
# Out:
#        Name  Age  Salary
# 0     Serna   22    1000
# 1    Ketsia    8    1000
# 2     Keren   17    1000
# 3  Tychique   20    1000
# 4     Premi    8    1000

# %%
df[df["Name"] == "Tychique"]
# Out:
#        Name  Age  Salary
# 3  Tychique   20    1000

# %%
df.drop(columns=["Salary"])
# Out:
#        Name  Age
# 0     Serna   22
# 1    Ketsia    8
# 2     Keren   17
# 3  Tychique   20
# 4     Premi    8

# %%
df.rename(columns={"Name":"Full Name"})
# Out:
#   Full Name  Age  Salary
# 0     Serna   22    1000
# 1    Ketsia    8    1000
# 2     Keren   17    1000
# 3  Tychique   20    1000
# 4     Premi    8    1000

# %%
df["Bonus Cut"] = df["Salary"]*0.10

# %%
df
# Out:
#        Name  Age  Salary  Bonus Cut
# 0     Serna   22    1000      100.0
# 1    Ketsia    8    1000      100.0
# 2     Keren   17    1000      100.0
# 3  Tychique   20    1000      100.0
# 4     Premi    8    1000      100.0

# %%
df["Age Category"] = df["Age"].apply(lambda x: "Young" if x <20 else "Old")

# %%
df
# Out:
#        Name  Age  Salary  Bonus Cut Age Category
# 0     Serna   22    1000      100.0          Old
# 1    Ketsia    8    1000      100.0        Young
# 2     Keren   17    1000      100.0        Young
# 3  Tychique   20    1000      100.0          Old
# 4     Premi    8    1000      100.0        Young

# %%
df.groupby("Age")["Salary"].sum()
# Out:
# Age
# 8     2000
# 17    1000
# 20    1000
# 22    1000
# Name: Salary, dtype: int64

# %%
df.sort_values("Age",ascending=True)
# Out:
#        Name  Age  Salary  Bonus Cut Age Category
# 1    Ketsia    8    1000      100.0        Young
# 4     Premi    8    1000      100.0        Young
# 2     Keren   17    1000      100.0        Young
# 3  Tychique   20    1000      100.0          Old
# 0     Serna   22    1000      100.0          Old

# %%
df.sort_values("Age")
# Out:
#        Name  Age  Salary  Bonus Cut Age Category
# 1    Ketsia    8    1000      100.0        Young
# 4     Premi    8    1000      100.0        Young
# 2     Keren   17    1000      100.0        Young
# 3  Tychique   20    1000      100.0          Old
# 0     Serna   22    1000      100.0          Old

# %%
import matplotlib.pyplot as plt

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
plt.show()

# %%
df.plot(kind="bar", x ="Name", y = "Salary")
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(kind="line",x="Age",y="Salary")
# Out:
# <Axes: xlabel='Age'>
