# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = np.loadtxt("ex7.csv",delimiter=",",dtype=str)
arr
# Out:
# array([['"a"', '"b"', '"c"'],
#        ['"1"', '"2"', '"3"'],
#        ['"1"', '"2"', '"3"']], dtype='<U3')

# %%
arr1 = pd.read_csv("ex7.csv",header=None)

# %%
arr1
# Out:
#    0  1  2
# 0  a  b  c
# 1  1  2  3
# 2  1  2  3

# %% [markdown]
# ## Generate values, make a csv and read it

# %%
arr2 = np.random.standard_normal(size=(100,10))

# %%
np.savetxt("new1.csv",arr2,delimiter=",")

# %%
arr3 = pd.DataFrame(arr2)

# %%
arr3
# Out:
#            0         1         2         3         4         5         6  \
# 0  -1.084796  0.743288 -0.116291 -1.288686 -1.717141 -0.206749 -0.223965
# 1   0.447434 -0.799619 -0.205447  1.210188 -0.619804  0.094897 -1.105264
# 2   1.635622  0.214778  0.665339 -0.702208  0.488183  0.378206 -0.210427
# 3   0.135472 -1.553147 -0.498274  1.578760  1.208290 -0.235608  0.535209
# 4  -1.251121  1.517262  0.075520 -2.129995  1.433202  0.956485  0.986721
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.054906  0.280551 -1.401510 -1.357985  0.703964 -0.819488  0.722757
# 96 -0.832666  1.494332 -0.852814 -0.462606  0.023600 -0.384488 -1.200297
# 97 -1.228444  2.143498  0.453933 -0.962743  1.021236  1.799823 -0.200038
# 98 -0.715536 -0.116652  0.521971  0.038743  1.616033  0.290562  1.868289
# 99  1.092461 -1.071683  0.472694 -0.983832  0.483213  0.224013  0.261984
#
#            7         8         9
# 0   0.125675  0.455217  0.491614
# ...

# %%
arr3.to_csv("new2.csv")

# %%
arr5 = np.loadtxt("new1.csv",delimiter=",")

# %%
arr5
# Out:
# array([[-1.08479583e+00,  7.43288465e-01, -1.16290890e-01,
#         -1.28868604e+00, -1.71714107e+00, -2.06748985e-01,
#         -2.23965319e-01,  1.25675168e-01,  4.55217300e-01,
#          4.91614015e-01],
#        [ 4.47433936e-01, -7.99618604e-01, -2.05446845e-01,
#          1.21018785e+00, -6.19803941e-01,  9.48972407e-02,
#         -1.10526355e+00, -2.70018271e-01, -9.32835757e-01,
#         -4.19631431e-01],
#        [ 1.63562240e+00,  2.14778190e-01,  6.65339254e-01,
#         -7.02207635e-01,  4.88182724e-01,  3.78206244e-01,
#         -2.10426821e-01, -1.16255931e+00, -1.12655678e+00,
#         -6.18680744e-01],
#        [ 1.35472098e-01, -1.55314710e+00, -4.98273929e-01,
#          1.57875954e+00,  1.20829026e+00, -2.35607808e-01,
#          5.35209026e-01,  1.25041936e+00,  1.20709473e+00,
#          2.53649757e+00],
#        [-1.25112115e+00,  1.51726235e+00,  7.55197781e-02,
#         -2.12999541e+00,  1.43320203e+00,  9.56484779e-01,
# ...

# %%
arr6 = pd.read_csv("new2.csv",header=None)

# %%
arr6
# Out:
#        0         1         2         3         4         5         6   \
# 0     NaN  0.000000  1.000000  2.000000  3.000000  4.000000  5.000000
# 1     0.0 -1.084796  0.743288 -0.116291 -1.288686 -1.717141 -0.206749
# 2     1.0  0.447434 -0.799619 -0.205447  1.210188 -0.619804  0.094897
# 3     2.0  1.635622  0.214778  0.665339 -0.702208  0.488183  0.378206
# 4     3.0  0.135472 -1.553147 -0.498274  1.578760  1.208290 -0.235608
# ..    ...       ...       ...       ...       ...       ...       ...
# 96   95.0  1.054906  0.280551 -1.401510 -1.357985  0.703964 -0.819488
# 97   96.0 -0.832666  1.494332 -0.852814 -0.462606  0.023600 -0.384488
# 98   97.0 -1.228444  2.143498  0.453933 -0.962743  1.021236  1.799823
# 99   98.0 -0.715536 -0.116652  0.521971  0.038743  1.616033  0.290562
# 100  99.0  1.092461 -1.071683  0.472694 -0.983832  0.483213  0.224013
#
#            7         8         9         10
# 0    6.000000  7.000000  8.000000  9.000000
# ...

# %% [markdown]
# ## one array is created randomly and saved to a csv another is converted to a data frame before being made a csv

# %%
plt?
# Out:
# Type:        module
# String form: <module 'matplotlib.pyplot' from 'C:\\Users\\serna\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\matplotlib\\pyplot.py'>
# File:        c:\users\serna\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py
# Docstring:
# `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
# an implicit,  MATLAB-like, way of plotting.  It also opens figures on your
# screen, and acts as the figure GUI manager.
#
# pyplot is mainly intended for interactive plots and simple cases of
# programmatic plot generation::
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     x = np.arange(0, 5, 0.1)
#     y = np.sin(x)
#     plt.plot(x, y)
#
# The explicit object-oriented API is recommended for complex plots, though
# pyplot is still usually used to create the figure and often the axes in the
# figure. See `.pyplot.figure`, `.pyplot.subplots`, and
# ...

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\serna\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot(arr5[1:],color="pink",linestyle="solid",label="gag city")
plt.plot(arr5[2:],color="orange",linestyle="dotted",label="gag city")
plt.plot(arr5[3:],color="blue",linestyle="dashed",label="gag city")
plt.plot(arr5[4:],color="grey",linestyle="dashdot",label="gag city")
plt.legend()
plt.xlabel("Stages")
plt.ylabel("Monthly Frequency")
plt.title("Loadshedding Lottery")
plt.savefig("fig1.jpg",dpi=600)

# %%
realData = pd.read_excel(r"wfa_girls_0-to-13-weeks_zscores.xlsx")

# %%
realData.head()
# Out:
#    Week       L       M        S  SD3neg  SD2neg  SD1neg  SD0  SD1  SD2  SD3
# 0     0  0.3809  3.2322  0.14171     2.0     2.4     2.8  3.2  3.7  4.2  4.8
# 1     1  0.2671  3.3388  0.14600     2.1     2.5     2.9  3.3  3.9  4.4  5.1
# 2     2  0.2304  3.5693  0.14339     2.3     2.7     3.1  3.6  4.1  4.7  5.4
# 3     3  0.2024  3.8352  0.14060     2.5     2.9     3.3  3.8  4.4  5.0  5.7
# 4     4  0.1789  4.0987  0.13805     2.7     3.1     3.6  4.1  4.7  5.4  6.1

# %%
realData.tail()
# Out:
#     Week       L       M        S  SD3neg  SD2neg  SD1neg  SD0  SD1  SD2  SD3
# 9      9  0.0918  5.1842  0.12966     3.5     4.0     4.6  5.2  5.9  6.7  7.6
# 10    10  0.0779  5.3618  0.12861     3.6     4.1     4.7  5.4  6.1  6.9  7.8
# 11    11  0.0648  5.5295  0.12770     3.8     4.3     4.9  5.5  6.3  7.1  8.1
# 12    12  0.0525  5.6883  0.12691     3.9     4.4     5.0  5.7  6.5  7.3  8.3
# 13    13  0.0407  5.8393  0.12622     4.0     4.5     5.1  5.8  6.6  7.5  8.5
